# %% [markdown]
# <a href="https://colab.research.google.com/github/motorio0829/DL-for-AI/blob/main/chapter03_introduction_to_keras_and_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Introduction to Keras and TensorFlow

# %% [markdown]
# ## What's TensorFlow?

# %% [markdown]
# ## What's Keras?

# %% [markdown]
# ## Keras and TensorFlow: A brief history

# %% [markdown]
# ## Setting up a deep-learning workspace

# %% [markdown]
# ### Jupyter notebooks: The preferred way to run deep-learning experiments

# %% [markdown]
# ### Using Colaboratory

# %% [markdown]
# #### First steps with Colaboratory

# %% [markdown]
# #### Installing packages with pip

# %% [markdown]
# #### Using the GPU runtime

# %% [markdown]
# ## First steps with TensorFlow

# %% [markdown]
# #### Constant tensors and variables

# %% [markdown]
# **All-ones or all-zeros tensors**

# %%
import tensorflow as tf
x = tf.ones(shape=(2, 1))
print(x)
# Out:
# tf.Tensor(
# [[1.]
#  [1.]], shape=(2, 1), dtype=float32)

# %%
x = tf.ones((2,1))
print(x)
# Out:
# tf.Tensor(
# [[1.]
#  [1.]], shape=(2, 1), dtype=float32)

# %%
x = tf.zeros(shape=(2, 1))
print(x)

x = tf.zeros((2,1))
print(x)
# Out:
# tf.Tensor(
# [[0.]
#  [0.]], shape=(2, 1), dtype=float32)
# tf.Tensor(
# [[0.]
#  [0.]], shape=(2, 1), dtype=float32)

# %% [markdown]
# **Random tensors**

# %%
x = tf.random.normal(shape=(3, 1), mean=0., stddev=1.)
print(x)
# Out:
# tf.Tensor(
# [[-0.08489451]
#  [-1.3691925 ]
#  [-1.1304467 ]], shape=(3, 1), dtype=float32)

# %%
x2 = tf.random.normal(shape = (3,2), mean = 1, stddev = 2)
print(x2)
# Out:
# tf.Tensor(
# [[ 3.7441578   2.7018661 ]
#  [ 0.69782245  4.812644  ]
#  [-0.38858998  0.27204305]], shape=(3, 2), dtype=float32)

# %%
x = tf.random.normal(shape=(3,1), mean = 0, stddev = 1.)
print(x)
# Out:
# tf.Tensor(
# [[ 0.5671482]
#  [-1.5267148]
#  [-1.1650763]], shape=(3, 1), dtype=float32)

# %%
x = tf.random.uniform(shape=(3, 1), minval=0., maxval=1.)
print(x)
# Out:
# tf.Tensor(
# [[0.05000854]
#  [0.2246337 ]
#  [0.03183496]], shape=(3, 1), dtype=float32)

# %%
x2 = tf.random.uniform(shape = (3,2), minval = 5, maxval = 10)
print(x2)
# Out:
# tf.Tensor(
# [[6.360591  6.4652734]
#  [9.2673025 8.868029 ]
#  [6.0763035 9.861574 ]], shape=(3, 2), dtype=float32)

# %%
x = tf.random.uniform(shape = (3,1), minval = 0, maxval = 1)
print(x)
# Out:
# tf.Tensor(
# [[0.31320894]
#  [0.7399807 ]
#  [0.19788778]], shape=(3, 1), dtype=float32)

# %% [markdown]
# **NumPy arrays are assignable**

# %%
import numpy as np
x = np.ones(shape=(2, 2))
print(x)
x[0, 0] = 0.
print(x)
# Out:
# [[1. 1.]
#  [1. 1.]]
# [[0. 1.]
#  [1. 1.]]

# %% [markdown]
# **Creating a TensorFlow variable**
# <br> tf.Variable

# %%
v = tf.Variable(initial_value=tf.random.normal(shape=(3, 1)))
print(v)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[-0.5948407],
#        [-2.6794882],
#        [-1.6246775]], dtype=float32)>

# %%
v2 = tf.Variable(initial_value = tf.random.normal(shape = (3,2)))
print(v2)
type(v2)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=float32, numpy=
# array([[ 0.26678607,  2.0010328 ],
#        [ 1.3021967 , -0.8957274 ],
#        [ 0.9356791 ,  0.5603778 ]], dtype=float32)>
# tensorflow.python.ops.resource_variable_ops.ResourceVariable

# %% [markdown]
# **Assigning a value to a TensorFlow variable**

# %%
v.assign(tf.ones((3, 1)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[1.],
#        [1.],
#        [1.]], dtype=float32)>

# %% [markdown]
# **Assigning a value to a subset of a TensorFlow variable**

# %%
v[0, 0].assign(3.)
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[3.],
#        [1.],
#        [1.]], dtype=float32)>

# %% [markdown]
# **Using `assign_add`**

# %%
v.assign_add(tf.ones((3, 1)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[4.],
#        [2.],
#        [2.]], dtype=float32)>

# %%
v2.assign_add(tf.ones(shape = (3,2)))
v2
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=float32, numpy=
# array([[1.2667861, 3.0010328],
#        [2.3021967, 0.1042726],
#        [1.9356791, 1.5603778]], dtype=float32)>

# %% [markdown]
# #### Tensor operations: Doing math in TensorFlow

# %% [markdown]
# **A few basic math operations**

# %%
a = tf.ones((2, 2))
b = tf.square(a)
print(b)
c = tf.sqrt(a)
print(b)
d = b + c
print(d)
e = tf.matmul(a, b)
print(e)
e *= d
print(e)
# Out:
# tf.Tensor(
# [[1. 1.]
#  [1. 1.]], shape=(2, 2), dtype=float32)
# tf.Tensor(
# [[1. 1.]
#  [1. 1.]], shape=(2, 2), dtype=float32)
# tf.Tensor(
# [[2. 2.]
#  [2. 2.]], shape=(2, 2), dtype=float32)
# tf.Tensor(
# [[2. 2.]
#  [2. 2.]], shape=(2, 2), dtype=float32)
# tf.Tensor(
# [[4. 4.]
#  [4. 4.]], shape=(2, 2), dtype=float32)

# %% [markdown]
# #### A second look at the GradientTape API

# %% [markdown]
# **Using the `GradientTape`**

# %%
input_var = tf.Variable(initial_value=3.)
# tf.Variable로 넣어야 역전파시 가중치 업데이트가 가능하다
# 학습 파라미터는 항상 Constant가 아닌 Variable로 설정해야됨
print(input_var)
with tf.GradientTape() as tape:
   result = tf.square(input_var) # x^2
gradient = tape.gradient(result, input_var)
print(gradient)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=3.0>
# tf.Tensor(6.0, shape=(), dtype=float32)

# %% [markdown]
# **Using `GradientTape` with constant tensor inputs**

# %%
input_const = tf.constant(3.)
with tf.GradientTape() as tape:
   tape.watch(input_const)
   result = tf.square(input_const)
gradient = tape.gradient(result, input_const)
gradient
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=6.0>

# %% [markdown]
# **Using nested gradient tapes to compute second-order gradients**

# %%
time = tf.Variable(0.)
with tf.GradientTape() as outer_tape:
    with tf.GradientTape() as inner_tape:
        position =  4.9 * time ** 2
    speed = inner_tape.gradient(position, time) # 내부 tape에서 1번 미분하고 0을 넣으면 9.8 * x = 0
acceleration = outer_tape.gradient(speed, time) # 외부 tape에서 1번 더 미분하고 0을 넣으면 9.8
print(speed)
print(acceleration)
# Out:
# tf.Tensor(0.0, shape=(), dtype=float32)
# tf.Tensor(9.8, shape=(), dtype=float32)

# %% [markdown]
# #### An end-to-end example: A linear classifier in pure TensorFlow

# %% [markdown]
# **Generating two classes of random points in a 2D plane**

# %%
num_samples_per_class = 1000
negative_samples = np.random.multivariate_normal(
    mean=[0, 3],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)
positive_samples = np.random.multivariate_normal(
    mean=[3, 0],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)

# %% [markdown]
# **Stacking the two classes into an array with shape (2000, 2)**

# %%
inputs = np.vstack((negative_samples, positive_samples)).astype(np.float32)

# %% [markdown]
# **Generating the corresponding targets (0 and 1)**

# %%
targets = np.vstack((np.zeros((num_samples_per_class, 1), dtype="float32"),
                     np.ones((num_samples_per_class, 1), dtype="float32")))

# %% [markdown]
# **Plotting the two point classes**

# %%
import matplotlib.pyplot as plt
plt.scatter(inputs[:, 0], inputs[:, 1], c=targets[:, 0])
plt.show()

# %% [markdown]
# **Creating the linear classifier variables**

# %%
input_dim = 2
output_dim = 1
W = tf.Variable(initial_value=tf.random.uniform(shape=(input_dim, output_dim)))
b = tf.Variable(initial_value=tf.zeros(shape=(output_dim,)))

# %% [markdown]
# **The forward pass function**

# %%
def model(inputs):
    return tf.matmul(inputs, W) #+ b

# %% [markdown]
# **The mean squared error loss function**

# %%
def square_loss(targets, predictions):
    per_sample_losses = tf.square(targets - predictions)
    return tf.reduce_mean(per_sample_losses)

# %% [markdown]
# **The training step function**

# %%
learning_rate = 0.1

def training_step(inputs, targets):
    with tf.GradientTape() as tape:
        predictions = model(inputs)
        loss = square_loss(targets, predictions)
    #grad_loss_wrt_W, grad_loss_wrt_b = tape.gradient(loss, [W, b])
    grad_loss_wrt_W = tape.gradient(loss, W)
    W.assign_sub(grad_loss_wrt_W * learning_rate) #W.assign_sub(substract)
    #b.assign_sub(grad_loss_wrt_b * learning_rate)
    return loss

# %% [markdown]
# **The batch training loop**

# %%
for step in range(20):
    loss = training_step(inputs, targets)
    print(f"Loss at step {step}: {loss:.4f}")
# Out:
# Loss at step 0: 6.7418
# Loss at step 1: 0.2192
# Loss at step 2: 0.0911
# Loss at step 3: 0.0883
# Loss at step 4: 0.0883
# Loss at step 5: 0.0883
# Loss at step 6: 0.0883
# Loss at step 7: 0.0883
# Loss at step 8: 0.0883
# Loss at step 9: 0.0883
# Loss at step 10: 0.0883
# Loss at step 11: 0.0883
# Loss at step 12: 0.0883
# Loss at step 13: 0.0883
# Loss at step 14: 0.0883
# Loss at step 15: 0.0883
# Loss at step 16: 0.0883
# Loss at step 17: 0.0883
# Loss at step 18: 0.0883
# Loss at step 19: 0.0883

# %%
predictions = model(inputs)
plt.scatter(inputs[:, 0], inputs[:, 1], c=predictions[:, 0] > 0.5)
plt.show()

# %%
x = np.linspace(-1, 4, 100)
y = - W[0] /  W[1] * x + (0.5 - b) / W[1]
plt.plot(x, y, "-r")
plt.scatter(inputs[:, 0], inputs[:, 1], c=predictions[:, 0] > 0.5)

# %%
for step in range(20):
    loss = training_step(inputs, targets)
    print(f"Loss at step {step}: {loss:.4f}")
# Out:
# Loss at step 0: 0.0883
# Loss at step 1: 0.0883
# Loss at step 2: 0.0883
# Loss at step 3: 0.0883
# Loss at step 4: 0.0883
# Loss at step 5: 0.0883
# Loss at step 6: 0.0883
# Loss at step 7: 0.0883
# Loss at step 8: 0.0883
# Loss at step 9: 0.0883
# Loss at step 10: 0.0883
# Loss at step 11: 0.0883
# Loss at step 12: 0.0883
# Loss at step 13: 0.0883
# Loss at step 14: 0.0883
# Loss at step 15: 0.0883
# Loss at step 16: 0.0883
# Loss at step 17: 0.0883
# Loss at step 18: 0.0883
# Loss at step 19: 0.0883

# %%
predictions = model(inputs)
plt.scatter(inputs[:, 0], inputs[:, 1], c=predictions[:, 0] > 0.5)
plt.show()

# %%
x = np.linspace(-1, 4, 100)
y = - W[0] /  W[1] * x + (0.5 - b) / W[1]
plt.plot(x, y, "-r")
plt.scatter(inputs[:, 0], inputs[:, 1], c=predictions[:, 0] > 0.5)

# %% [markdown]
# ## Anatomy of a neural network: Understanding core Keras APIs

# %% [markdown]
# ### Layers: The building blocks of deep learning

# %% [markdown]
# #### The base Layer class in Keras

# %% [markdown]
# **A `Dense` layer implemented as a `Layer` subclass**

# %%
from tensorflow import keras

class SimpleDense(keras.layers.Layer):

    def __init__(self, units, activation=None):
        super().__init__()
        self.units = units
        self.activation = activation

    def build(self, input_shape):
        input_dim = input_shape[-1]
        self.W = self.add_weight(shape=(input_dim, self.units),
                                 initializer="random_normal")
        self.b = self.add_weight(shape=(self.units,),
                                 initializer="zeros")

    def call(self, inputs):
        y = tf.matmul(inputs, self.W) + self.b
        if self.activation is not None:
            y = self.activation(y)
        return y

# %%
my_dense = SimpleDense(units=32, activation=tf.nn.relu)
input_tensor = tf.ones(shape=(2, 784))
output_tensor = my_dense(input_tensor)
print(output_tensor.shape)
# Out:
# (2, 32)

# %% [markdown]
# #### Automatic shape inference: Building layers on the fly

# %%
from tensorflow.keras import layers
layer = layers.Dense(32, activation="relu")

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
model = keras.Sequential([
    SimpleDense(32, activation="relu"),
    SimpleDense(64, activation="relu"),
    SimpleDense(32, activation="relu"),
    SimpleDense(10, activation="softmax")
])

# %% [markdown]
# ### From layers to models

# %% [markdown]
# ### The "compile" step: Configuring the learning process

# %%
model = keras.Sequential([keras.layers.Dense(1)])
model.compile(optimizer="rmsprop",
              loss="mean_squared_error",
              metrics=["accuracy"])

# %%
model.compile(optimizer=keras.optimizers.RMSprop(),
              loss=keras.losses.MeanSquaredError(),
              metrics=[keras.metrics.BinaryAccuracy()])

# %% [markdown]
# ### Picking a loss function

# %% [markdown]
# ### Understanding the fit() method

# %% [markdown]
# **Calling `fit()` with NumPy data**

# %%
history = model.fit(
    inputs,
    targets,
    epochs=5,
    batch_size=128
)
# Out:
# Epoch 1/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - binary_accuracy: 0.0650 - loss: 7.5382
# Epoch 2/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.0691 - loss: 7.4380
# Epoch 3/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.0673 - loss: 7.0084
# Epoch 4/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.0812 - loss: 6.5902
# Epoch 5/5
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.0802 - loss: 6.4277

# %%
history.history
# Out:
# {'binary_accuracy': [0.06949999928474426,
#   0.07100000232458115,
#   0.07450000196695328,
#   0.07699999958276749,
#   0.07900000363588333],
#  'loss': [7.508477210998535,
#   7.181308746337891,
#   6.9053544998168945,
#   6.637547016143799,
#   6.378700256347656]}

# %% [markdown]
# ### Monitoring loss and metrics on validation data

# %% [markdown]
# **Using the `validation_data` argument**

# %%
model = keras.Sequential([keras.layers.Dense(1)])
model.compile(optimizer=keras.optimizers.RMSprop(learning_rate=0.1),
              loss=keras.losses.MeanSquaredError(),
              metrics=[keras.metrics.BinaryAccuracy()])

indices_permutation = np.random.permutation(len(inputs)) # index shuffle을 위한 것
shuffled_inputs = inputs[indices_permutation] # input과 target을 shuffle 해줌
shuffled_targets = targets[indices_permutation]

num_validation_samples = int(0.3 * lenㄴ(inputs)) # 총 input 수의 0.3배수를 validation set으로 이용
val_inputs = shuffled_inputs[:num_validation_samples] # 검증용 슬라이싱
val_targets = shuffled_targets[:num_validation_samples] # 검증용 슬라이싱
training_inputs = shuffled_inputs[num_validation_samples:] # 나머지 70%는 그대로 훈련 데이터셋으로 사용
training_targets = shuffled_targets[num_validation_samples:] # 훈련 데이터셋 사용
model.fit(
    training_inputs,
    training_targets,
    epochs=5,
    batch_size=20,
    validation_data=(val_inputs, val_targets) # validation data 지정
)
# Out:
# Epoch 1/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - binary_accuracy: 0.8690 - loss: 0.2372 - val_binary_accuracy: 0.9783 - val_loss: 0.1056
# Epoch 2/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.9618 - loss: 0.0618 - val_binary_accuracy: 0.9417 - val_loss: 0.1068
# Epoch 3/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.9596 - loss: 0.0771 - val_binary_accuracy: 0.9967 - val_loss: 0.0303
# Epoch 4/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.9710 - loss: 0.0530 - val_binary_accuracy: 0.9950 - val_loss: 0.0468
# Epoch 5/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9706 - loss: 0.0704 - val_binary_accuracy: 0.9950 - val_loss: 0.0365

# %% [markdown]
# ### Inference: Using a model after training

# %%
predictions = model.predict(val_inputs, batch_size=128)
print(predictions[:10])
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[ 0.6096759 ]
#  [ 0.05764461]
#  [ 1.3177981 ]
#  [-0.07509631]
#  [ 0.47066456]
#  [ 0.3549365 ]
#  [-0.02197152]
#  [ 0.04313463]
#  [ 0.14797711]
#  [ 1.0296636 ]]

# %% [markdown]
# ## Summary
